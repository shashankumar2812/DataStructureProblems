# %% [markdown]
# # Problem
#
# Leetcode Link: https://leetcode.com/problems/trapping-rain-water/
#
# Given a sorted (in ascending order) integer array nums of n elements and a target value, write a function to search target in nums. If target exists, then return its index, otherwise return -1.
#
#
# ![image.png](attachment:image.png)

# %%
from typing import List

def trap(height: List[int]) -> int:
    if len(height)==0: return 0
    water=0
    for i in range(len(height)):
        l_max=max([height[j] for j in range(len(height)) if j<i], default=0)
        r_max=max([height[j] for j in range(len(height)) if j>i], default=0)
        min_height=min(l_max,r_max)
        water+=max(min_height-height[i],0)

    return water

# %%
arr=[2,1,0,2]

# %%
trap(arr)
# Out:
# i: 0
# height at i: 2
# left array: []
# left array max: 0
# right array: [1, 0, 2]
# right array max: 2
# min height: 0
# water: 0
# i: 1
# height at i: 1
# left array: [2]
# left array max: 2
# right array: [0, 2]
# right array max: 2
# min height: 2
# water: 1
# i: 2
# height at i: 0
# left array: [2, 1]
# left array max: 2
# right array: [2]
# right array max: 2
# min height: 2
# water: 3
# i: 3
# height at i: 2
# left array: [2, 1, 0]
# left array max: 2
# right array: []
# right array max: 0
# min height: 0
# water: 3
# 3
