# %% [markdown]
# # Problem
#
# Leetcode Link: https://leetcode.com/explore/interview/card/amazon/76/array-and-strings/2963/
#
# Given n non-negative integers a1, a2, ..., an , where each represents a point at coordinate (i, ai). n vertical lines are drawn such that the two endpoints of line i is at (i, ai) and (i, 0). Find two lines, which together with x-axis forms a container, such that the container contains the most water.
#
# Note: You may not slant the container and n is at least 2.
#
#
#
# ![image.png](attachment:image.png)
#
# The above vertical lines are represented by array [1,8,6,2,5,4,8,3,7]. In this case, the max area of water (blue section) the container can contain is 49.
#
#
#
# Example:
#
# Input: [1,8,6,2,5,4,8,3,7]
# Output: 49

# %% [markdown]
# ## Solution 1-O(N2)

# %%
from typing import List
def find_max_area_1(height: List[int])->int:
    if len(height)<=1: return 0
    max_area=0
    for i,val1 in enumerate(height):
        for j,val2 in enumerate(height):
            h=min(val1,val2)
            max_area=max(max_area,h*(j-i))
    return max_area

# %%
find_max_area_1([1,8,6,2,5,4,8,3,7])
# Out:
# 49

# %% [markdown]
# ## Solution 2-O(N)

# %%
def find_max_area_2(height: List[int])->int:
    if len(height)<=1: return 0
    max_area=0
    left=0
    right=len(height)-1
    while(left<right):
        h=min(height[left], height[right])
        max_area=max(max_area, h*(right-left))
        if (height[left]<height[right]):
            left+=1
        else:
            right-=1
    return max_area

# %%
find_max_area_2([1,8,6,2,5,4,8,3,7])
# Out:
# 49
